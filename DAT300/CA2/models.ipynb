# %%
# Build model_2
model_2 = Sequential([
    Conv2D(64, (5, 5), activation='relu', input_shape=(28, 28, 1), padding='same'),
    BatchNormalization(),
    MaxPool2D(pool_size=(2, 2), strides=2),

    Conv2D(128, (3, 3), activation='relu', padding='same'),
    BatchNormalization(),
    MaxPool2D(pool_size=(2, 2), strides=2),
    
    Conv2D(128, (3, 3), activation='relu', padding='same'),
    BatchNormalization(),
    MaxPool2D(pool_size=(2, 2), strides=2),
    
    Flatten(),        
    Dense(32, activation='relu'),          
    Dropout(0.6),
    Dense(10, activation='softmax'),
])


# Compile model_2
model_2.compile(
    optimizer= Adam(learning_rate=0.0001),
    loss= CategoricalCrossentropy(),
    metrics=['accuracy'])


es = EarlyStopping(monitor='val_loss', patience=3, restore_best_weights=True)
# Train model_2
history = model_2.fit(
    X_train, y_train_cat, 
    batch_size = 10,                        
    epochs = 10,                           
    validation_split = 1/6,
    callbacks = [es]  
)

# %%
model_3 = Sequential([
    Conv2D(64, (5, 5), activation='relu', input_shape=(28, 28, 1), padding='same'),
    BatchNormalization(),
    MaxPool2D(pool_size=(2, 2), strides=2),

    Conv2D(128, (3, 3), activation='relu', padding='same'),
    BatchNormalization(),
    MaxPool2D(pool_size=(2, 2), strides=2),
    
    Conv2D(32, (3, 3), activation='relu', padding='same'),
    BatchNormalization(),
    MaxPool2D(pool_size=(2, 2), strides=2),
    
    Flatten(),        
    Dense(32, activation='relu'),          
    Dropout(0.6),
    Dense(10, activation='softmax'),
])


# Compile model_3
model_3.compile(
    optimizer= Adam(learning_rate=0.0001),
    loss= CategoricalCrossentropy(),
    metrics=['accuracy'])

es = EarlyStopping(monitor='val_loss', patience=3, restore_best_weights=True)
# Train model_3
history_3 = model_3.fit(
    X_train, y_train_cat, 
    batch_size = 10,                        
    epochs = 10,                           
    validation_split = 1/6,
    callbacks = [es]  
)

# %%
# DETTE ER MODELLEN SOM HAR PRESTERT BEST PÅ KAGGLE TIL NÅ

model = Sequential([
    Conv2D(128, (5, 5), activation='relu', input_shape=(28, 28, 1), padding='same'),     # 64 filters
    BatchNormalization(),
    MaxPool2D(pool_size=(3, 3), strides=3),

    Conv2D(256, (5, 5), activation='relu', padding='same'),                             # 128 filters
    BatchNormalization(),
    MaxPool2D(pool_size=(3, 3), strides=3),
    
    Conv2D(32, (3, 3), activation='relu', padding='same'),
    BatchNormalization(),
    MaxPool2D(pool_size=(3, 3), strides=3),
    
    Flatten(),        
    Dense(32, activation='relu'),          
    Dropout(0.6),
    Dense(10, activation='softmax'),
])


# Compile model_4
model.compile(
    optimizer= Adam(learning_rate=0.0001),
    loss= CategoricalCrossentropy(),
    metrics=['accuracy'])

es = EarlyStopping(monitor='val_loss', patience=2, restore_best_weights=True)
# Train model_4
history_4 = model.fit(
    X_train, y_train_cat, 
    batch_size = 10,                        
    epochs = 10,                           
    validation_split = 1/6,
    callbacks = [es]  
)

# %%
## DENNE FUNGERER BRA

model = Sequential([
    Conv2D(128, (5, 5), activation='relu', input_shape=(28, 28, 1), padding='same'),     # 64 filters
    BatchNormalization(),
    MaxPool2D(pool_size=(3, 3), strides=3),

    Conv2D(256, (5, 5), activation='relu', padding='same'),                             # 128 filters
    BatchNormalization(),
    MaxPool2D(pool_size=(3, 3), strides=3),
    
    Conv2D(32, (3, 3), activation='relu', padding='same'),
    BatchNormalization(),
    MaxPool2D(pool_size=(3, 3), strides=3),
    
    Flatten(),        
    Dense(32, activation='relu'),          
    Dropout(0.6),
    Dense(10, activation='softmax'),
])


# Compile model_4
model.compile(
    optimizer= Adam(learning_rate=0.0001),
    loss= CategoricalCrossentropy(),
    metrics=['accuracy'])

es = EarlyStopping(monitor='val_loss', patience=2, restore_best_weights=True)
# Train model_4
history_4 = model.fit(
    X_train, y_train_cat, 
    batch_size = 64,                        
    epochs = 10,                           
    validation_split = 1/6,
    callbacks = [es]  
)
